# %% [markdown]
# <a href="https://colab.research.google.com/github/janpeter19/BPL_YEAST_AIR_Fedbatch/blob/main/BPL_YEAST_AIR_Fedbatch_fmpy_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BPL_YEAST_AIR_Fedbatch script with FMPy
#
# The key library FMPy is installed.
#
# After the installation a small application BPL_YEAST_AIR_Fedbatch is loaded and run. You can continue with this example if you like.

# %%
# !lsb_release -a # Actual VM Ubuntu version used by Google
# Out:
# No LSB modules are available.
# Distributor ID:	Ubuntu
# Description:	Ubuntu 22.04.3 LTS
# Release:	22.04
# Codename:	jammy

# %%
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py312_24.3.0-0-Linux-x86_64.sh
# !chmod +x Miniconda3-py312_24.3.0-0-Linux-x86_64.sh
# !bash ./Miniconda3-py312_24.3.0-0-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.12/site-packages/')
# Out:
# --2024-05-17 07:03:13--  https://repo.anaconda.com/miniconda/Miniconda3-py312_24.3.0-0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 143351488 (137M) [application/octet-stream]
# Saving to: ‘Miniconda3-py312_24.3.0-0-Linux-x86_64.sh’
#
# Miniconda3-py312_24 100%[===================>] 136.71M   135MB/s    in 1.0s
#
# 2024-05-17 07:03:14 (135 MB/s) - ‘Miniconda3-py312_24.3.0-0-Linux-x86_64.sh’ saved [143351488/143351488]
#
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.

# %%
# !conda update -n base -c defaults conda --yes
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-24.5.0               |  py312h06a4308_0         1.2 MB
#     frozendict-2.4.2           |  py312h06a4308_0          36 KB
#     openssl-3.0.13             |       h7f8727e_1         5.2 MB
#     ------------------------------------------------------------
#                                            Total:         6.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   frozendict         pkgs/main/linux-64::frozendict-2.4.2-py312h06a4308_0
#
# The following packages will be UPDATED:
#
#   conda                              24.3.0-py312h06a4308_0 --> 24.5.0-py312h06a4308_0
#   openssl                                 3.0.13-h7f8727e_0 --> 3.0.13-h7f8727e_1
#
#
#
# Downloading and Extracting Packages:
# openssl-3.0.13       | 5.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
# conda-24.5.0         | 1.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# openssl-3.0.13       | 5.2 MB    | :   0% 0.002997347135570501/1 [00:00<00:39, 39.84s/it]
# conda-24.5.0         | 1.2 MB    | :   1% 0.01293349794914382/1 [00:00<00:12, 12.50s/it]
#
# frozendict-2.4.2     | 36 KB     | :  44% 0.43853215920344746/1 [00:00<00:00,  2.61it/s]
#
# frozendict-2.4.2     | 36 KB     | : 100% 1.0/1 [00:00<00:00,  2.61it/s]
# conda-24.5.0         | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.87it/s]
#
#
#
#
# done
# done
# done

# %%
# !conda --version
# !python --version
# Out:
# conda 24.5.0
# Python 3.12.2

# %%
# !conda install -c conda-forge fmpy --yes # Install the key package
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - fmpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            2_gnu          23 KB  conda-forge
#     abseil-cpp-20211102.0      |       h27087fc_1         1.1 MB  conda-forge
#     anyio-4.3.0                |     pyhd8ed1ab_0         100 KB  conda-forge
#     argon2-cffi-23.1.0         |     pyhd8ed1ab_0          18 KB  conda-forge
#     argon2-cffi-bindings-21.2.0|  py312h98912ed_4          34 KB  conda-forge
#     arrow-1.3.0                |     pyhd8ed1ab_0          98 KB  conda-forge
#     arrow-cpp-14.0.2           |       h374c478_1        11.7 MB
#     asttokens-2.4.1            |     pyhd8ed1ab_0          28 KB  conda-forge
#     async-lru-2.0.4            |     pyhd8ed1ab_0          15 KB  conda-forge
#     attrs-23.2.0               |     pyh71513ae_0          53 KB  conda-forge
#     aws-c-auth-0.6.19          |       h5eee18b_0          99 KB
#     aws-c-cal-0.5.20           |       hff2c3d7_3          43 KB  conda-forge
#     aws-c-common-0.8.5         |       h166bdaf_0         198 KB  conda-forge
#     aws-c-compression-0.2.16   |       hf5f93bc_0          18 KB  conda-forge
#     aws-c-event-stream-0.2.15  |       h6a678d5_0          50 KB
#     aws-c-http-0.6.25          |       h5eee18b_0         200 KB
#     aws-c-io-0.13.10           |       h2666983_0         140 KB  conda-forge
#     aws-c-mqtt-0.7.13          |       h5eee18b_0          67 KB
#     aws-c-s3-0.1.51            |       hdbd6064_0          71 KB
#     aws-c-sdkutils-0.1.6       |       hf5f93bc_1          52 KB  conda-forge
#     aws-checksums-0.1.13       |       hf5f93bc_5          51 KB  conda-forge
#     aws-crt-cpp-0.18.16        |       h6a678d5_0         213 KB
#     aws-sdk-cpp-1.10.55        |       h721c034_0         2.5 MB
#     babel-2.14.0               |     pyhd8ed1ab_0         7.3 MB  conda-forge
#     beautifulsoup4-4.12.3      |     pyha770c72_0         115 KB  conda-forge
#     blas-1.1                   |         openblas           1 KB  conda-forge
#     bleach-6.1.0               |     pyhd8ed1ab_0         128 KB  conda-forge
#     blinker-1.8.2              |     pyhd8ed1ab_0          14 KB  conda-forge
#     bokeh-3.4.1                |     pyhd8ed1ab_0         4.5 MB  conda-forge
#     boost-cpp-1.82.0           |       hdb19cb5_2          11 KB
#     bottleneck-1.3.8           |  py312hc7c0aa3_0         137 KB  conda-forge
#     brotli-1.0.9               |       h166bdaf_9          20 KB  conda-forge
#     brotli-bin-1.0.9           |       h166bdaf_9          20 KB  conda-forge
#     cached-property-1.5.2      |       hd8ed1ab_1           4 KB  conda-forge
#     cached_property-1.5.2      |     pyha770c72_1          11 KB  conda-forge
#     certifi-2024.2.2           |     pyhd8ed1ab_0         157 KB  conda-forge
#     click-8.1.7                |unix_pyh707e725_0          82 KB  conda-forge
#     cloudpickle-3.0.0          |     pyhd8ed1ab_0          24 KB  conda-forge
#     comm-0.2.2                 |     pyhd8ed1ab_0          12 KB  conda-forge
#     conda-24.5.0               |  py312h7900ff3_0         1.2 MB  conda-forge
#     contourpy-1.2.0            |  py312hdb19cb5_0         238 KB
#     cycler-0.12.1              |     pyhd8ed1ab_0          13 KB  conda-forge
#     cytoolz-0.12.3             |  py312h98912ed_0         385 KB  conda-forge
#     dash-2.17.0                |     pyhd8ed1ab_0         5.0 MB  conda-forge
#     dash-bootstrap-components-1.6.0|     pyhd8ed1ab_0         117 KB  conda-forge
#     dask-2024.5.0              |     pyhd8ed1ab_0           7 KB  conda-forge
#     dask-core-2024.5.0         |     pyhd8ed1ab_0         861 KB  conda-forge
#     dask-expr-1.1.0            |     pyhd8ed1ab_0         154 KB  conda-forge
#     dbus-1.13.18               |       hb2f20db_0         504 KB
#     debugpy-1.6.7              |  py312h6a678d5_0         2.0 MB
#     decorator-5.1.1            |     pyhd8ed1ab_0          12 KB  conda-forge
#     defusedxml-0.7.1           |     pyhd8ed1ab_0          23 KB  conda-forge
#     distributed-2024.5.0       |     pyhd8ed1ab_0         777 KB  conda-forge
#     entrypoints-0.4            |     pyhd8ed1ab_0           9 KB  conda-forge
#     exceptiongroup-1.2.0       |     pyhd8ed1ab_2          20 KB  conda-forge
#     executing-2.0.1            |     pyhd8ed1ab_0          27 KB  conda-forge
#     flask-3.0.3                |     pyhd8ed1ab_0          79 KB  conda-forge
#     fmpy-0.3.20                |       h13ae965_0          10 KB  conda-forge
#     fmpy-base-0.3.20           |  py312ha770c72_0         3.2 MB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_2         1.5 MB  conda-forge
#     fontconfig-2.14.2          |       h14ed4e7_0         266 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     fonttools-4.51.0           |  py312h98912ed_0         2.7 MB  conda-forge
#     fqdn-1.5.1                 |     pyhd8ed1ab_0          14 KB  conda-forge
#     freetype-2.12.1            |       h267a509_2         620 KB  conda-forge
#     fsspec-2024.5.0            |     pyhff2d567_0         211 KB  conda-forge
#     gettext-0.21.1             |       h27087fc_0         4.1 MB  conda-forge
#     gflags-2.2.2               |    he1b5a44_1004         114 KB  conda-forge
#     glib-2.70.2                |       h780b84a_4         430 KB  conda-forge
#     glib-tools-2.70.2          |       h780b84a_4         106 KB  conda-forge
#     glog-0.5.0                 |       h48cff8f_0         104 KB  conda-forge
#     grpc-cpp-1.48.2            |       he1ff14a_1         4.8 MB
#     gst-plugins-base-1.14.1    |       h6a678d5_1         2.2 MB
#     gstreamer-1.14.1           |       h5eee18b_1         1.7 MB
#     h11-0.14.0                 |     pyhd8ed1ab_0          47 KB  conda-forge
#     h2-4.1.0                   |     pyhd8ed1ab_0          46 KB  conda-forge
#     hpack-4.0.0                |     pyh9f0ad1d_0          25 KB  conda-forge
#     httpcore-1.0.5             |     pyhd8ed1ab_0          45 KB  conda-forge
#     httpx-0.27.0               |     pyhd8ed1ab_0          63 KB  conda-forge
#     hyperframe-6.0.1           |     pyhd8ed1ab_0          14 KB  conda-forge
#     importlib-metadata-7.1.0   |     pyha770c72_0          26 KB  conda-forge
#     importlib_metadata-7.1.0   |       hd8ed1ab_0           9 KB  conda-forge
#     importlib_resources-6.4.0  |     pyhd8ed1ab_0          32 KB  conda-forge
#     ipykernel-6.29.3           |     pyhd33586a_0         116 KB  conda-forge
#     ipython-8.24.0             |     pyh707e725_0         582 KB  conda-forge
#     isoduration-20.11.0        |     pyhd8ed1ab_0          17 KB  conda-forge
#     itsdangerous-2.2.0         |     pyhd8ed1ab_0          19 KB  conda-forge
#     jedi-0.19.1                |     pyhd8ed1ab_0         822 KB  conda-forge
#     jinja2-3.1.4               |     pyhd8ed1ab_0         109 KB  conda-forge
#     jpeg-9e                    |       h0b41bf4_3         235 KB  conda-forge
#     json5-0.9.25               |     pyhd8ed1ab_0          27 KB  conda-forge
#     jsonschema-4.22.0          |     pyhd8ed1ab_0          72 KB  conda-forge
#     jsonschema-specifications-2023.12.1|     pyhd8ed1ab_0          16 KB  conda-forge
#     jsonschema-with-format-nongpl-4.22.0|     pyhd8ed1ab_0           7 KB  conda-forge
#     jupyter-lsp-2.2.5          |     pyhd8ed1ab_0          54 KB  conda-forge
#     jupyter_client-8.6.1       |     pyhd8ed1ab_0         104 KB  conda-forge
#     jupyter_core-5.7.2         |  py312h7900ff3_0          91 KB  conda-forge
#     jupyter_events-0.10.0      |     pyhd8ed1ab_0          21 KB  conda-forge
#     jupyter_server-2.14.0      |     pyhd8ed1ab_0         317 KB  conda-forge
#     jupyter_server_terminals-0.5.3|     pyhd8ed1ab_0          19 KB  conda-forge
#     jupyterlab-4.2.0           |     pyhd8ed1ab_1         7.6 MB  conda-forge
#     jupyterlab_pygments-0.3.0  |     pyhd8ed1ab_1          18 KB  conda-forge
#     jupyterlab_server-2.27.1   |     pyhd8ed1ab_0          48 KB  conda-forge
#     kaleido-core-0.2.1         |       h3644ca4_0        59.2 MB  conda-forge
#     kiwisolver-1.4.4           |  py312h6a678d5_0          68 KB
#     lark-1.1.9                 |     pyhd8ed1ab_0          90 KB  conda-forge
#     lcms2-2.15                 |       hfd0df8a_0         235 KB  conda-forge
#     lerc-3.0                   |       h9c3ff4c_0         216 KB  conda-forge
#     libboost-1.82.0            |       h109eef0_2        19.5 MB
#     libbrotlicommon-1.0.9      |       h166bdaf_9          69 KB  conda-forge
#     libbrotlidec-1.0.9         |       h166bdaf_9          32 KB  conda-forge
#     libbrotlienc-1.0.9         |       h166bdaf_9         259 KB  conda-forge
#     libclang-14.0.6            |default_hc6dbbc7_1         137 KB
#     libclang13-14.0.6          |default_he11475f_1         9.8 MB
#     libcups-2.4.2              |       h2d74bed_1         4.5 MB
#     libdeflate-1.17            |       h0b41bf4_0          63 KB  conda-forge
#     libevent-2.1.12            |       hf998b51_1         417 KB  conda-forge
#     libexpat-2.5.0             |       hcb278e6_1          76 KB  conda-forge
#     libgcc-ng-13.2.0           |       h77fa898_7         758 KB  conda-forge
#     libgfortran-ng-13.2.0      |       h69a702a_7          24 KB  conda-forge
#     libgfortran5-13.2.0        |       hca663fb_7         1.4 MB  conda-forge
#     libglib-2.70.2             |       h174f98d_4         3.1 MB  conda-forge
#     libgomp-13.2.0             |       h77fa898_7         412 KB  conda-forge
#     libiconv-1.17              |       hd590300_2         689 KB  conda-forge
#     libllvm14-14.0.6           |       hdb19cb5_3        33.4 MB
#     libnsl-2.0.1               |       hd590300_0          33 KB  conda-forge
#     libopenblas-0.3.27         |pthreads_h413a1c8_0         5.3 MB  conda-forge
#     libpng-1.6.43              |       h2797004_0         281 KB  conda-forge
#     libpq-12.17                |       hdbd6064_0         2.4 MB
#     libprotobuf-3.20.3         |       he621ea3_0         2.4 MB
#     libsodium-1.0.18           |       h36c2ea0_1         366 KB  conda-forge
#     libsqlite-3.45.3           |       h2797004_0         840 KB  conda-forge
#     libthrift-0.15.0           |       h1795dd8_2         4.0 MB
#     libtiff-4.5.1              |       h6a678d5_0         533 KB
#     libuuid-2.38.1             |       h0b41bf4_0          33 KB  conda-forge
#     libwebp-base-1.4.0         |       hd590300_0         429 KB  conda-forge
#     libxcb-1.16                |       hd590300_0         386 KB  conda-forge
#     libxcrypt-4.4.36           |       hd590300_1          98 KB  conda-forge
#     libxkbcommon-1.0.3         |       he3ba5ed_0         581 KB  conda-forge
#     libxslt-1.1.37             |       h873f0b0_0         251 KB  conda-forge
#     libzlib-1.2.13             |       hd590300_5          60 KB  conda-forge
#     locket-1.0.0               |     pyhd8ed1ab_0           8 KB  conda-forge
#     lxml-5.2.1                 |  py312hdbbb534_0         1.4 MB
#     lz4-4.3.3                  |  py312h03f37cb_0          38 KB  conda-forge
#     markupsafe-2.1.5           |  py312h98912ed_0          26 KB  conda-forge
#     mathjax-2.7.7              |       ha770c72_3        21.2 MB  conda-forge
#     matplotlib-base-3.8.4      |  py312h526ad5a_0         7.6 MB
#     matplotlib-inline-0.1.7    |     pyhd8ed1ab_0          14 KB  conda-forge
#     mistune-3.0.2              |     pyhd8ed1ab_0          64 KB  conda-forge
#     msgpack-python-1.0.3       |  py312hdb19cb5_0          35 KB
#     munkres-1.1.4              |     pyh9f0ad1d_0          12 KB  conda-forge
#     mysql-5.7.20               |    hf484d3e_1001        79.2 MB  conda-forge
#     nbclient-0.10.0            |     pyhd8ed1ab_0          27 KB  conda-forge
#     nbconvert-core-7.16.4      |     pyhd8ed1ab_0         185 KB  conda-forge
#     nbformat-5.10.4            |     pyhd8ed1ab_0          99 KB  conda-forge
#     nest-asyncio-1.6.0         |     pyhd8ed1ab_0          11 KB  conda-forge
#     notebook-7.2.0             |     pyhd8ed1ab_0         3.8 MB  conda-forge
#     notebook-shim-0.2.4        |     pyhd8ed1ab_0          16 KB  conda-forge
#     nspr-4.35                  |       h6a678d5_0         244 KB
#     nss-3.89.1                 |       h6a678d5_0         2.1 MB
#     numexpr-2.8.7              |  py312he7dcb8a_0         149 KB
#     numpy-1.26.4               |  py312h2809609_0          10 KB
#     numpy-base-1.26.4          |  py312he1a6c75_0         7.7 MB
#     openblas-0.3.27            |pthreads_h7a3da1a_0         5.5 MB  conda-forge
#     openjpeg-2.4.0             |       h3ad879b_0         331 KB
#     openssl-3.3.0              |       hd590300_0         2.8 MB  conda-forge
#     orc-1.7.4                  |       h6c59b99_1         1.1 MB  conda-forge
#     overrides-7.7.0            |     pyhd8ed1ab_0          30 KB  conda-forge
#     pandas-2.2.1               |  py312h526ad5a_0        15.4 MB
#     pandocfilters-1.5.0        |     pyhd8ed1ab_0          11 KB  conda-forge
#     parso-0.8.4                |     pyhd8ed1ab_0          73 KB  conda-forge
#     partd-1.4.2                |     pyhd8ed1ab_0          20 KB  conda-forge
#     pcre-8.45                  |       h9c3ff4c_0         253 KB  conda-forge
#     pexpect-4.9.0              |     pyhd8ed1ab_0          52 KB  conda-forge
#     pickleshare-0.7.5          |          py_1003           9 KB  conda-forge
#     pillow-10.3.0              |  py312h5eee18b_0         915 KB
#     pkgutil-resolve-name-1.3.10|     pyhd8ed1ab_1          11 KB  conda-forge
#     plotly-5.22.0              |     pyhd8ed1ab_0         5.1 MB  conda-forge
#     ply-3.11                   |     pyhd8ed1ab_2          48 KB  conda-forge
#     prometheus_client-0.20.0   |     pyhd8ed1ab_0          48 KB  conda-forge
#     prompt-toolkit-3.0.42      |     pyha770c72_0         264 KB  conda-forge
#     psutil-5.9.8               |  py312h98912ed_0         475 KB  conda-forge
#     pthread-stubs-0.4          |    h36c2ea0_1001           5 KB  conda-forge
#     ptyprocess-0.7.0           |     pyhd3deb0d_0          16 KB  conda-forge
#     pure_eval-0.2.2            |     pyhd8ed1ab_0          14 KB  conda-forge
#     pyarrow-14.0.2             |  py312hb107042_0         4.6 MB
#     pyarrow-hotfix-0.6         |     pyhd8ed1ab_0          13 KB  conda-forge
#     pygments-2.18.0            |     pyhd8ed1ab_0         859 KB  conda-forge
#     pyparsing-3.0.9            |     pyhd8ed1ab_0          79 KB  conda-forge
#     pyqt-5.15.10               |  py312h6a678d5_0         5.0 MB
#     pyqt5-sip-12.13.0          |  py312h5eee18b_0          88 KB
#     pyqtgraph-0.13.7           |     pyhd8ed1ab_0         1.4 MB  conda-forge
#     pyqtwebengine-5.15.10      |  py312h6a678d5_0         153 KB
#     python-3.12.2              |hab00c5b_0_cpython        30.8 MB  conda-forge
#     python-dateutil-2.9.0      |     pyhd8ed1ab_0         218 KB  conda-forge
#     python-fastjsonschema-2.19.1|     pyhd8ed1ab_0         220 KB  conda-forge
#     python-json-logger-2.0.7   |     pyhd8ed1ab_0          13 KB  conda-forge
#     python-kaleido-0.2.1       |     pyhd8ed1ab_0          18 KB  conda-forge
#     python-tzdata-2024.1       |     pyhd8ed1ab_0         141 KB  conda-forge
#     python_abi-3.12            |          4_cp312           6 KB  conda-forge
#     pytz-2024.1                |     pyhd8ed1ab_0         184 KB  conda-forge
#     pyyaml-6.0.1               |  py312h98912ed_1         192 KB  conda-forge
#     pyzmq-25.1.2               |  py312h6a678d5_0         533 KB
#     qt-main-5.15.2             |      h53bd1ea_10        53.7 MB
#     qt-webengine-5.15.9        |       h9ab4d14_7        53.8 MB
#     re2-2022.04.01             |       h27087fc_0         212 KB  conda-forge
#     referencing-0.35.1         |     pyhd8ed1ab_0          41 KB  conda-forge
#     retrying-1.3.3             |             py_2          11 KB  conda-forge
#     rfc3339-validator-0.1.4    |     pyhd8ed1ab_0           8 KB  conda-forge
#     rfc3986-validator-0.1.1    |     pyh9f0ad1d_0           8 KB  conda-forge
#     rpds-py-0.18.1             |  py312h4413252_0         901 KB  conda-forge
#     s2n-1.3.27                 |       h1b5e8cb_0         374 KB  conda-forge
#     scipy-1.12.0               |  py312h2809609_0        23.3 MB
#     send2trash-1.8.3           |     pyh0d859eb_0          22 KB  conda-forge
#     sip-6.7.12                 |  py312h6a678d5_0         553 KB
#     six-1.16.0                 |     pyh6c4a22f_0          14 KB  conda-forge
#     snappy-1.1.9               |       hbd366e4_1          35 KB  conda-forge
#     sniffio-1.3.1              |     pyhd8ed1ab_0          15 KB  conda-forge
#     sortedcontainers-2.4.0     |     pyhd8ed1ab_0          26 KB  conda-forge
#     soupsieve-2.5              |     pyhd8ed1ab_1          36 KB  conda-forge
#     stack_data-0.6.2           |     pyhd8ed1ab_0          26 KB  conda-forge
#     tblib-3.0.0                |     pyhd8ed1ab_0          17 KB  conda-forge
#     tenacity-8.3.0             |     pyhd8ed1ab_0          23 KB  conda-forge
#     terminado-0.18.1           |     pyh0d859eb_0          22 KB  conda-forge
#     tinycss2-1.3.0             |     pyhd8ed1ab_0          25 KB  conda-forge
#     tk-8.6.13                  |noxft_h4845f30_101         3.2 MB  conda-forge
#     tomli-2.0.1                |     pyhd8ed1ab_0          16 KB  conda-forge
#     toolz-0.12.1               |     pyhd8ed1ab_0          51 KB  conda-forge
#     tornado-6.4                |  py312h98912ed_0         821 KB  conda-forge
#     traitlets-5.14.3           |     pyhd8ed1ab_0         108 KB  conda-forge
#     types-python-dateutil-2.9.0.20240316|     pyhd8ed1ab_0          21 KB  conda-forge
#     typing-extensions-4.11.0   |       hd8ed1ab_0          10 KB  conda-forge
#     typing_extensions-4.11.0   |     pyha770c72_0          37 KB  conda-forge
#     typing_utils-0.1.0         |     pyhd8ed1ab_0          14 KB  conda-forge
#     uri-template-1.3.0         |     pyhd8ed1ab_0          23 KB  conda-forge
#     utf8proc-2.6.1             |       h5eee18b_1          93 KB
#     wcwidth-0.2.13             |     pyhd8ed1ab_0          32 KB  conda-forge
#     webcolors-1.13             |     pyhd8ed1ab_0          18 KB  conda-forge
#     webencodings-0.5.1         |     pyhd8ed1ab_2          15 KB  conda-forge
#     websocket-client-1.8.0     |     pyhd8ed1ab_0          46 KB  conda-forge
#     werkzeug-3.0.3             |     pyhd8ed1ab_0         237 KB  conda-forge
#     xorg-libxau-1.0.11         |       hd590300_0          14 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h7f98852_0          19 KB  conda-forge
#     xyzservices-2024.4.0       |     pyhd8ed1ab_0          45 KB  conda-forge
#     yaml-0.2.5                 |       h7f98852_2          87 KB  conda-forge
#     zeromq-4.3.5               |       h6a678d5_0         366 KB
#     zict-3.0.0                 |     pyhd8ed1ab_0          35 KB  conda-forge
#     zipp-3.17.0                |     pyhd8ed1ab_0          19 KB  conda-forge
#     zlib-1.2.13                |       hd590300_5          91 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       565.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   abseil-cpp         conda-forge/linux-64::abseil-cpp-20211102.0-h27087fc_1
#   anyio              conda-forge/noarch::anyio-4.3.0-pyhd8ed1ab_0
#   argon2-cffi        conda-forge/noarch::argon2-cffi-23.1.0-pyhd8ed1ab_0
#   argon2-cffi-bindi~ conda-forge/linux-64::argon2-cffi-bindings-21.2.0-py312h98912ed_4
#   arrow              conda-forge/noarch::arrow-1.3.0-pyhd8ed1ab_0
#   arrow-cpp          pkgs/main/linux-64::arrow-cpp-14.0.2-h374c478_1
#   asttokens          conda-forge/noarch::asttokens-2.4.1-pyhd8ed1ab_0
#   async-lru          conda-forge/noarch::async-lru-2.0.4-pyhd8ed1ab_0
#   attrs              conda-forge/noarch::attrs-23.2.0-pyh71513ae_0
#   aws-c-auth         pkgs/main/linux-64::aws-c-auth-0.6.19-h5eee18b_0
#   aws-c-cal          conda-forge/linux-64::aws-c-cal-0.5.20-hff2c3d7_3
#   aws-c-common       conda-forge/linux-64::aws-c-common-0.8.5-h166bdaf_0
#   aws-c-compression  conda-forge/linux-64::aws-c-compression-0.2.16-hf5f93bc_0
#   aws-c-event-stream pkgs/main/linux-64::aws-c-event-stream-0.2.15-h6a678d5_0
#   aws-c-http         pkgs/main/linux-64::aws-c-http-0.6.25-h5eee18b_0
#   aws-c-io           conda-forge/linux-64::aws-c-io-0.13.10-h2666983_0
#   aws-c-mqtt         pkgs/main/linux-64::aws-c-mqtt-0.7.13-h5eee18b_0
#   aws-c-s3           pkgs/main/linux-64::aws-c-s3-0.1.51-hdbd6064_0
#   aws-c-sdkutils     conda-forge/linux-64::aws-c-sdkutils-0.1.6-hf5f93bc_1
#   aws-checksums      conda-forge/linux-64::aws-checksums-0.1.13-hf5f93bc_5
#   aws-crt-cpp        pkgs/main/linux-64::aws-crt-cpp-0.18.16-h6a678d5_0
#   aws-sdk-cpp        pkgs/main/linux-64::aws-sdk-cpp-1.10.55-h721c034_0
#   babel              conda-forge/noarch::babel-2.14.0-pyhd8ed1ab_0
#   beautifulsoup4     conda-forge/noarch::beautifulsoup4-4.12.3-pyha770c72_0
#   blas               conda-forge/linux-64::blas-1.1-openblas
#   bleach             conda-forge/noarch::bleach-6.1.0-pyhd8ed1ab_0
#   blinker            conda-forge/noarch::blinker-1.8.2-pyhd8ed1ab_0
#   bokeh              conda-forge/noarch::bokeh-3.4.1-pyhd8ed1ab_0
#   boost-cpp          pkgs/main/linux-64::boost-cpp-1.82.0-hdb19cb5_2
#   bottleneck         conda-forge/linux-64::bottleneck-1.3.8-py312hc7c0aa3_0
#   brotli             conda-forge/linux-64::brotli-1.0.9-h166bdaf_9
#   brotli-bin         conda-forge/linux-64::brotli-bin-1.0.9-h166bdaf_9
#   cached-property    conda-forge/noarch::cached-property-1.5.2-hd8ed1ab_1
#   cached_property    conda-forge/noarch::cached_property-1.5.2-pyha770c72_1
#   click              conda-forge/noarch::click-8.1.7-unix_pyh707e725_0
#   cloudpickle        conda-forge/noarch::cloudpickle-3.0.0-pyhd8ed1ab_0
#   comm               conda-forge/noarch::comm-0.2.2-pyhd8ed1ab_0
#   contourpy          pkgs/main/linux-64::contourpy-1.2.0-py312hdb19cb5_0
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_0
#   cytoolz            conda-forge/linux-64::cytoolz-0.12.3-py312h98912ed_0
#   dash               conda-forge/noarch::dash-2.17.0-pyhd8ed1ab_0
#   dash-bootstrap-co~ conda-forge/noarch::dash-bootstrap-components-1.6.0-pyhd8ed1ab_0
#   dask               conda-forge/noarch::dask-2024.5.0-pyhd8ed1ab_0
#   dask-core          conda-forge/noarch::dask-core-2024.5.0-pyhd8ed1ab_0
#   dask-expr          conda-forge/noarch::dask-expr-1.1.0-pyhd8ed1ab_0
#   dbus               pkgs/main/linux-64::dbus-1.13.18-hb2f20db_0
#   debugpy            pkgs/main/linux-64::debugpy-1.6.7-py312h6a678d5_0
#   decorator          conda-forge/noarch::decorator-5.1.1-pyhd8ed1ab_0
#   defusedxml         conda-forge/noarch::defusedxml-0.7.1-pyhd8ed1ab_0
#   distributed        conda-forge/noarch::distributed-2024.5.0-pyhd8ed1ab_0
#   entrypoints        conda-forge/noarch::entrypoints-0.4-pyhd8ed1ab_0
#   exceptiongroup     conda-forge/noarch::exceptiongroup-1.2.0-pyhd8ed1ab_2
#   executing          conda-forge/noarch::executing-2.0.1-pyhd8ed1ab_0
#   flask              conda-forge/noarch::flask-3.0.3-pyhd8ed1ab_0
#   fmpy               conda-forge/noarch::fmpy-0.3.20-h13ae965_0
#   fmpy-base          conda-forge/linux-64::fmpy-base-0.3.20-py312ha770c72_0
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_2
#   fontconfig         conda-forge/linux-64::fontconfig-2.14.2-h14ed4e7_0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   fonttools          conda-forge/linux-64::fonttools-4.51.0-py312h98912ed_0
#   fqdn               conda-forge/noarch::fqdn-1.5.1-pyhd8ed1ab_0
#   freetype           conda-forge/linux-64::freetype-2.12.1-h267a509_2
#   fsspec             conda-forge/noarch::fsspec-2024.5.0-pyhff2d567_0
#   gettext            conda-forge/linux-64::gettext-0.21.1-h27087fc_0
#   gflags             conda-forge/linux-64::gflags-2.2.2-he1b5a44_1004
#   glib               conda-forge/linux-64::glib-2.70.2-h780b84a_4
#   glib-tools         conda-forge/linux-64::glib-tools-2.70.2-h780b84a_4
#   glog               conda-forge/linux-64::glog-0.5.0-h48cff8f_0
#   grpc-cpp           pkgs/main/linux-64::grpc-cpp-1.48.2-he1ff14a_1
#   gst-plugins-base   pkgs/main/linux-64::gst-plugins-base-1.14.1-h6a678d5_1
#   gstreamer          pkgs/main/linux-64::gstreamer-1.14.1-h5eee18b_1
#   h11                conda-forge/noarch::h11-0.14.0-pyhd8ed1ab_0
#   h2                 conda-forge/noarch::h2-4.1.0-pyhd8ed1ab_0
#   hpack              conda-forge/noarch::hpack-4.0.0-pyh9f0ad1d_0
#   httpcore           conda-forge/noarch::httpcore-1.0.5-pyhd8ed1ab_0
#   httpx              conda-forge/noarch::httpx-0.27.0-pyhd8ed1ab_0
#   hyperframe         conda-forge/noarch::hyperframe-6.0.1-pyhd8ed1ab_0
#   importlib-metadata conda-forge/noarch::importlib-metadata-7.1.0-pyha770c72_0
#   importlib_metadata conda-forge/noarch::importlib_metadata-7.1.0-hd8ed1ab_0
#   importlib_resourc~ conda-forge/noarch::importlib_resources-6.4.0-pyhd8ed1ab_0
#   ipykernel          conda-forge/noarch::ipykernel-6.29.3-pyhd33586a_0
#   ipython            conda-forge/noarch::ipython-8.24.0-pyh707e725_0
#   isoduration        conda-forge/noarch::isoduration-20.11.0-pyhd8ed1ab_0
#   itsdangerous       conda-forge/noarch::itsdangerous-2.2.0-pyhd8ed1ab_0
#   jedi               conda-forge/noarch::jedi-0.19.1-pyhd8ed1ab_0
#   jinja2             conda-forge/noarch::jinja2-3.1.4-pyhd8ed1ab_0
#   jpeg               conda-forge/linux-64::jpeg-9e-h0b41bf4_3
#   json5              conda-forge/noarch::json5-0.9.25-pyhd8ed1ab_0
#   jsonschema         conda-forge/noarch::jsonschema-4.22.0-pyhd8ed1ab_0
#   jsonschema-specif~ conda-forge/noarch::jsonschema-specifications-2023.12.1-pyhd8ed1ab_0
#   jsonschema-with-f~ conda-forge/noarch::jsonschema-with-format-nongpl-4.22.0-pyhd8ed1ab_0
#   jupyter-lsp        conda-forge/noarch::jupyter-lsp-2.2.5-pyhd8ed1ab_0
#   jupyter_client     conda-forge/noarch::jupyter_client-8.6.1-pyhd8ed1ab_0
#   jupyter_core       conda-forge/linux-64::jupyter_core-5.7.2-py312h7900ff3_0
#   jupyter_events     conda-forge/noarch::jupyter_events-0.10.0-pyhd8ed1ab_0
#   jupyter_server     conda-forge/noarch::jupyter_server-2.14.0-pyhd8ed1ab_0
#   jupyter_server_te~ conda-forge/noarch::jupyter_server_terminals-0.5.3-pyhd8ed1ab_0
#   jupyterlab         conda-forge/noarch::jupyterlab-4.2.0-pyhd8ed1ab_1
#   jupyterlab_pygmen~ conda-forge/noarch::jupyterlab_pygments-0.3.0-pyhd8ed1ab_1
#   jupyterlab_server  conda-forge/noarch::jupyterlab_server-2.27.1-pyhd8ed1ab_0
#   kaleido-core       conda-forge/linux-64::kaleido-core-0.2.1-h3644ca4_0
#   kiwisolver         pkgs/main/linux-64::kiwisolver-1.4.4-py312h6a678d5_0
#   lark               conda-forge/noarch::lark-1.1.9-pyhd8ed1ab_0
#   lcms2              conda-forge/linux-64::lcms2-2.15-hfd0df8a_0
#   lerc               conda-forge/linux-64::lerc-3.0-h9c3ff4c_0
#   libboost           pkgs/main/linux-64::libboost-1.82.0-h109eef0_2
#   libbrotlicommon    conda-forge/linux-64::libbrotlicommon-1.0.9-h166bdaf_9
#   libbrotlidec       conda-forge/linux-64::libbrotlidec-1.0.9-h166bdaf_9
#   libbrotlienc       conda-forge/linux-64::libbrotlienc-1.0.9-h166bdaf_9
#   libclang           pkgs/main/linux-64::libclang-14.0.6-default_hc6dbbc7_1
#   libclang13         pkgs/main/linux-64::libclang13-14.0.6-default_he11475f_1
#   libcups            pkgs/main/linux-64::libcups-2.4.2-h2d74bed_1
#   libdeflate         conda-forge/linux-64::libdeflate-1.17-h0b41bf4_0
#   libevent           conda-forge/linux-64::libevent-2.1.12-hf998b51_1
#   libexpat           conda-forge/linux-64::libexpat-2.5.0-hcb278e6_1
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-13.2.0-h69a702a_7
#   libgfortran5       conda-forge/linux-64::libgfortran5-13.2.0-hca663fb_7
#   libglib            conda-forge/linux-64::libglib-2.70.2-h174f98d_4
#   libiconv           conda-forge/linux-64::libiconv-1.17-hd590300_2
#   libllvm14          pkgs/main/linux-64::libllvm14-14.0.6-hdb19cb5_3
#   libnsl             conda-forge/linux-64::libnsl-2.0.1-hd590300_0
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.27-pthreads_h413a1c8_0
#   libpng             conda-forge/linux-64::libpng-1.6.43-h2797004_0
#   libpq              pkgs/main/linux-64::libpq-12.17-hdbd6064_0
#   libprotobuf        pkgs/main/linux-64::libprotobuf-3.20.3-he621ea3_0
#   libsodium          conda-forge/linux-64::libsodium-1.0.18-h36c2ea0_1
#   libsqlite          conda-forge/linux-64::libsqlite-3.45.3-h2797004_0
#   libthrift          pkgs/main/linux-64::libthrift-0.15.0-h1795dd8_2
#   libtiff            pkgs/main/linux-64::libtiff-4.5.1-h6a678d5_0
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.4.0-hd590300_0
#   libxcb             conda-forge/linux-64::libxcb-1.16-hd590300_0
#   libxcrypt          conda-forge/linux-64::libxcrypt-4.4.36-hd590300_1
#   libxkbcommon       conda-forge/linux-64::libxkbcommon-1.0.3-he3ba5ed_0
#   libxslt            conda-forge/linux-64::libxslt-1.1.37-h873f0b0_0
#   libzlib            conda-forge/linux-64::libzlib-1.2.13-hd590300_5
#   locket             conda-forge/noarch::locket-1.0.0-pyhd8ed1ab_0
#   lxml               pkgs/main/linux-64::lxml-5.2.1-py312hdbbb534_0
#   lz4                conda-forge/linux-64::lz4-4.3.3-py312h03f37cb_0
#   markupsafe         conda-forge/linux-64::markupsafe-2.1.5-py312h98912ed_0
#   mathjax            conda-forge/linux-64::mathjax-2.7.7-ha770c72_3
#   matplotlib-base    pkgs/main/linux-64::matplotlib-base-3.8.4-py312h526ad5a_0
#   matplotlib-inline  conda-forge/noarch::matplotlib-inline-0.1.7-pyhd8ed1ab_0
#   mistune            conda-forge/noarch::mistune-3.0.2-pyhd8ed1ab_0
#   msgpack-python     pkgs/main/linux-64::msgpack-python-1.0.3-py312hdb19cb5_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   mysql              conda-forge/linux-64::mysql-5.7.20-hf484d3e_1001
#   nbclient           conda-forge/noarch::nbclient-0.10.0-pyhd8ed1ab_0
#   nbconvert-core     conda-forge/noarch::nbconvert-core-7.16.4-pyhd8ed1ab_0
#   nbformat           conda-forge/noarch::nbformat-5.10.4-pyhd8ed1ab_0
#   nest-asyncio       conda-forge/noarch::nest-asyncio-1.6.0-pyhd8ed1ab_0
#   notebook           conda-forge/noarch::notebook-7.2.0-pyhd8ed1ab_0
#   notebook-shim      conda-forge/noarch::notebook-shim-0.2.4-pyhd8ed1ab_0
#   nspr               pkgs/main/linux-64::nspr-4.35-h6a678d5_0
#   nss                pkgs/main/linux-64::nss-3.89.1-h6a678d5_0
#   numexpr            pkgs/main/linux-64::numexpr-2.8.7-py312he7dcb8a_0
#   numpy              pkgs/main/linux-64::numpy-1.26.4-py312h2809609_0
#   numpy-base         pkgs/main/linux-64::numpy-base-1.26.4-py312he1a6c75_0
#   openblas           conda-forge/linux-64::openblas-0.3.27-pthreads_h7a3da1a_0
#   openjpeg           pkgs/main/linux-64::openjpeg-2.4.0-h3ad879b_0
#   orc                conda-forge/linux-64::orc-1.7.4-h6c59b99_1
#   overrides          conda-forge/noarch::overrides-7.7.0-pyhd8ed1ab_0
#   pandas             pkgs/main/linux-64::pandas-2.2.1-py312h526ad5a_0
#   pandocfilters      conda-forge/noarch::pandocfilters-1.5.0-pyhd8ed1ab_0
#   parso              conda-forge/noarch::parso-0.8.4-pyhd8ed1ab_0
#   partd              conda-forge/noarch::partd-1.4.2-pyhd8ed1ab_0
#   pcre               conda-forge/linux-64::pcre-8.45-h9c3ff4c_0
#   pexpect            conda-forge/noarch::pexpect-4.9.0-pyhd8ed1ab_0
#   pickleshare        conda-forge/noarch::pickleshare-0.7.5-py_1003
#   pillow             pkgs/main/linux-64::pillow-10.3.0-py312h5eee18b_0
#   pkgutil-resolve-n~ conda-forge/noarch::pkgutil-resolve-name-1.3.10-pyhd8ed1ab_1
#   plotly             conda-forge/noarch::plotly-5.22.0-pyhd8ed1ab_0
#   ply                conda-forge/noarch::ply-3.11-pyhd8ed1ab_2
#   prometheus_client  conda-forge/noarch::prometheus_client-0.20.0-pyhd8ed1ab_0
#   prompt-toolkit     conda-forge/noarch::prompt-toolkit-3.0.42-pyha770c72_0
#   psutil             conda-forge/linux-64::psutil-5.9.8-py312h98912ed_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   ptyprocess         conda-forge/noarch::ptyprocess-0.7.0-pyhd3deb0d_0
#   pure_eval          conda-forge/noarch::pure_eval-0.2.2-pyhd8ed1ab_0
#   pyarrow            pkgs/main/linux-64::pyarrow-14.0.2-py312hb107042_0
#   pyarrow-hotfix     conda-forge/noarch::pyarrow-hotfix-0.6-pyhd8ed1ab_0
#   pygments           conda-forge/noarch::pygments-2.18.0-pyhd8ed1ab_0
#   pyparsing          conda-forge/noarch::pyparsing-3.0.9-pyhd8ed1ab_0
#   pyqt               pkgs/main/linux-64::pyqt-5.15.10-py312h6a678d5_0
#   pyqt5-sip          pkgs/main/linux-64::pyqt5-sip-12.13.0-py312h5eee18b_0
#   pyqtgraph          conda-forge/noarch::pyqtgraph-0.13.7-pyhd8ed1ab_0
#   pyqtwebengine      pkgs/main/linux-64::pyqtwebengine-5.15.10-py312h6a678d5_0
#   python-dateutil    conda-forge/noarch::python-dateutil-2.9.0-pyhd8ed1ab_0
#   python-fastjsonsc~ conda-forge/noarch::python-fastjsonschema-2.19.1-pyhd8ed1ab_0
#   python-json-logger conda-forge/noarch::python-json-logger-2.0.7-pyhd8ed1ab_0
#   python-kaleido     conda-forge/noarch::python-kaleido-0.2.1-pyhd8ed1ab_0
#   python-tzdata      conda-forge/noarch::python-tzdata-2024.1-pyhd8ed1ab_0
#   python_abi         conda-forge/linux-64::python_abi-3.12-4_cp312
#   pytz               conda-forge/noarch::pytz-2024.1-pyhd8ed1ab_0
#   pyyaml             conda-forge/linux-64::pyyaml-6.0.1-py312h98912ed_1
#   pyzmq              pkgs/main/linux-64::pyzmq-25.1.2-py312h6a678d5_0
#   qt-main            pkgs/main/linux-64::qt-main-5.15.2-h53bd1ea_10
#   qt-webengine       pkgs/main/linux-64::qt-webengine-5.15.9-h9ab4d14_7
#   re2                conda-forge/linux-64::re2-2022.04.01-h27087fc_0
#   referencing        conda-forge/noarch::referencing-0.35.1-pyhd8ed1ab_0
#   retrying           conda-forge/noarch::retrying-1.3.3-py_2
#   rfc3339-validator  conda-forge/noarch::rfc3339-validator-0.1.4-pyhd8ed1ab_0
#   rfc3986-validator  conda-forge/noarch::rfc3986-validator-0.1.1-pyh9f0ad1d_0
#   rpds-py            conda-forge/linux-64::rpds-py-0.18.1-py312h4413252_0
#   s2n                conda-forge/linux-64::s2n-1.3.27-h1b5e8cb_0
#   scipy              pkgs/main/linux-64::scipy-1.12.0-py312h2809609_0
#   send2trash         conda-forge/noarch::send2trash-1.8.3-pyh0d859eb_0
#   sip                pkgs/main/linux-64::sip-6.7.12-py312h6a678d5_0
#   six                conda-forge/noarch::six-1.16.0-pyh6c4a22f_0
#   snappy             conda-forge/linux-64::snappy-1.1.9-hbd366e4_1
#   sniffio            conda-forge/noarch::sniffio-1.3.1-pyhd8ed1ab_0
#   sortedcontainers   conda-forge/noarch::sortedcontainers-2.4.0-pyhd8ed1ab_0
#   soupsieve          conda-forge/noarch::soupsieve-2.5-pyhd8ed1ab_1
#   stack_data         conda-forge/noarch::stack_data-0.6.2-pyhd8ed1ab_0
#   tblib              conda-forge/noarch::tblib-3.0.0-pyhd8ed1ab_0
#   tenacity           conda-forge/noarch::tenacity-8.3.0-pyhd8ed1ab_0
#   terminado          conda-forge/noarch::terminado-0.18.1-pyh0d859eb_0
#   tinycss2           conda-forge/noarch::tinycss2-1.3.0-pyhd8ed1ab_0
#   tomli              conda-forge/noarch::tomli-2.0.1-pyhd8ed1ab_0
#   toolz              conda-forge/noarch::toolz-0.12.1-pyhd8ed1ab_0
#   tornado            conda-forge/linux-64::tornado-6.4-py312h98912ed_0
#   traitlets          conda-forge/noarch::traitlets-5.14.3-pyhd8ed1ab_0
#   types-python-date~ conda-forge/noarch::types-python-dateutil-2.9.0.20240316-pyhd8ed1ab_0
#   typing-extensions  conda-forge/noarch::typing-extensions-4.11.0-hd8ed1ab_0
#   typing_extensions  conda-forge/noarch::typing_extensions-4.11.0-pyha770c72_0
#   typing_utils       conda-forge/noarch::typing_utils-0.1.0-pyhd8ed1ab_0
#   uri-template       conda-forge/noarch::uri-template-1.3.0-pyhd8ed1ab_0
#   utf8proc           pkgs/main/linux-64::utf8proc-2.6.1-h5eee18b_1
#   wcwidth            conda-forge/noarch::wcwidth-0.2.13-pyhd8ed1ab_0
#   webcolors          conda-forge/noarch::webcolors-1.13-pyhd8ed1ab_0
#   webencodings       conda-forge/noarch::webencodings-0.5.1-pyhd8ed1ab_2
#   websocket-client   conda-forge/noarch::websocket-client-1.8.0-pyhd8ed1ab_0
#   werkzeug           conda-forge/noarch::werkzeug-3.0.3-pyhd8ed1ab_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.11-hd590300_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#   xyzservices        conda-forge/noarch::xyzservices-2024.4.0-pyhd8ed1ab_0
#   yaml               conda-forge/linux-64::yaml-0.2.5-h7f98852_2
#   zeromq             pkgs/main/linux-64::zeromq-4.3.5-h6a678d5_0
#   zict               conda-forge/noarch::zict-3.0.0-pyhd8ed1ab_0
#   zipp               conda-forge/noarch::zipp-3.17.0-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   libgcc-ng          pkgs/main::libgcc-ng-11.2.0-h1234567_1 --> conda-forge::libgcc-ng-13.2.0-h77fa898_7
#   libgomp              pkgs/main::libgomp-11.2.0-h1234567_1 --> conda-forge::libgomp-13.2.0-h77fa898_7
#   libuuid              pkgs/main::libuuid-1.41.5-h5eee18b_0 --> conda-forge::libuuid-2.38.1-h0b41bf4_0
#   openssl              pkgs/main::openssl-3.0.13-h7f8727e_1 --> conda-forge::openssl-3.3.0-hd590300_0
#   tk                        pkgs/main::tk-8.6.12-h1ccaba5_0 --> conda-forge::tk-8.6.13-noxft_h4845f30_101
#   zlib                    pkgs/main::zlib-1.2.13-h5eee18b_0 --> conda-forge::zlib-1.2.13-hd590300_5
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   _libgcc_mutex           pkgs/main::_libgcc_mutex-0.1-main --> conda-forge::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex          pkgs/main::_openmp_mutex-5.1-1_gnu --> conda-forge::_openmp_mutex-4.5-2_gnu
#   certifi            pkgs/main/linux-64::certifi-2024.2.2-~ --> conda-forge/noarch::certifi-2024.2.2-pyhd8ed1ab_0
#   conda              pkgs/main::conda-24.5.0-py312h06a4308~ --> conda-forge::conda-24.5.0-py312h7900ff3_0
#   python                pkgs/main::python-3.12.2-h996f2a0_0 --> conda-forge::python-3.12.2-hab00c5b_0_cpython
#
#
#
# Downloading and Extracting Packages:
# mysql-5.7.20         | 79.2 MB   | :   0% 0/1 [00:00<?, ?it/s]
# kaleido-core-0.2.1   | 59.2 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# qt-webengine-5.15.9  | 53.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
# qt-main-5.15.2       | 53.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libllvm14-14.0.6     | 33.4 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# python-3.12.2        | 30.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# scipy-1.12.0         | 23.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# mathjax-2.7.7        | 21.2 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# pandas-2.2.1         | 15.4 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# arrow-cpp-14.0.2     | 11.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# libclang13-14.0.6    | 9.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# numpy-base-1.26.4    | 7.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 7.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyterlab-4.2.0     | 7.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# babel-2.14.0         | 7.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openblas-0.3.27      | 5.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.27   | 5.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# plotly-5.22.0        | 5.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# qt-webengine-5.15.9  | 53.8 MB   | :   0% 0.00029068176868217617/1 [00:00<14:09, 849.33s/it]
#
# mysql-5.7.20         | 79.2 MB   | :   0% 0.00019718423464384747/1 [00:00<30:23, 1823.53s/it]
#
#
# qt-main-5.15.2       | 53.7 MB   | :   0% 0.00029119184998373156/1 [00:00<20:43, 1244.09s/it]
#
#
#
# libllvm14-14.0.6     | 33.4 MB   | :   0% 0.00046843413253998403/1 [00:00<12:52, 772.76s/it]
# kaleido-core-0.2.1   | 59.2 MB   | :   0% 0.000263832842570537/1 [00:00<24:49, 1489.43s/it]
#
# mysql-5.7.20         | 79.2 MB   | :   4% 0.03845092575555026/1 [00:00<00:08,  9.25s/it]
#
#
# qt-main-5.15.2       | 53.7 MB   | :   4% 0.044261161197527196/1 [00:00<00:07,  8.01s/it]
#
#
#
# libllvm14-14.0.6     | 33.4 MB   | :  10% 0.10399237742387644/1 [00:00<00:03,  3.51s/it]
# mysql-5.7.20         | 79.2 MB   | :   7% 0.07197224564500433/1 [00:00<00:05,  5.77s/it]
#
# qt-webengine-5.15.9  | 53.8 MB   | :  23% 0.22673177957209742/1 [00:00<00:01,  2.04s/it]
#
#
# qt-main-5.15.2       | 53.7 MB   | :   9% 0.09172543274487543/1 [00:00<00:04,  4.45s/it]
#
#
#
# libllvm14-14.0.6     | 33.4 MB   | :  19% 0.19252642847393342/1 [00:00<00:01,  2.20s/it]
# mysql-5.7.20         | 79.2 MB   | :  12% 0.11515559303200693/1 [00:00<00:03,  4.03s/it]
#
# qt-webengine-5.15.9  | 53.8 MB   | :  29% 0.28951904160744746/1 [00:00<00:01,  1.92s/it]
#
#
# qt-main-5.15.2       | 53.7 MB   | :  16% 0.15578763974129636/1 [00:00<00:02,  2.97s/it]
#
#
#
# libllvm14-14.0.6     | 33.4 MB   | :  30% 0.30260844962082967/1 [00:00<00:01,  1.59s/it]
# mysql-5.7.20         | 79.2 MB   | :  16% 0.16425446745832495/1 [00:00<00:02,  3.13s/it]
#
# qt-webengine-5.15.9  | 53.8 MB   | :  36% 0.3560851666356658/1 [00:00<00:01,  1.80s/it]
#
#
# qt-main-5.15.2       | 53.7 MB   | :  22% 0.22101461413765225/1 [00:00<00:01,  2.36s/it]
#
#
#
# libllvm14-14.0.6     | 33.4 MB   | :  39% 0.39348467133358656/1 [00:00<00:00,  1.41s/it]
# mysql-5.7.20         | 79.2 MB   | :  21% 0.20960684142640987/1 [00:00<00:02,  2.85s/it]
#
#
# qt-main-5.15.2       | 53.7 MB   | :  30% 0.2964333032834387/1 [00:00<00:01,  1.93s/it]
#
# qt-webengine-5.15.9  | 53.8 MB   | :  43% 0.4281742452688455/1 [00:00<00:00,  1.70s/it]
#
#
#
# libllvm14-14.0.6     | 33.4 MB   | :  50% 0.5045035607455628/1 [00:00<00:00,  1.26s/it]
# mysql-5.7.20         | 79.2 MB   | :  25% 0.2539732942212755/1 [00:00<00:02,  2.70s/it]
#
# qt-webengine-5.15.9  | 53.8 MB   | :  49% 0.4941590067596995/1 [00:00<00:00,  1.68s/it]
#
#
# qt-main-5.15.2       | 53.7 MB   | :  36% 0.35612763253010365/1 [00:01<00:01,  2.13s/it]
#
#
#
# libllvm14-14.0.6     | 33.4 MB   | :  59% 0.5944429141932397/1 [00:01<00:00,  1.35s/it]
# mysql-5.7.20         | 79.2 MB   | :  29% 0.29459324655790814/1 [00:01<00:02,  3.09s/it]
#
# qt-webengine-5.15.9  | 53.8 MB   | :  56% 0.556074223489003/1 [00:01<00:00,  2.13s/it]
#
#
#
# libllvm14-14.0.6     | 33.4 MB   | :  68% 0.6764188873877369/1 [00:01<00:00,  1.51s/it]
#
#
# qt-main-5.15.2       | 53.7 MB   | :  41% 0.4091245492271428/1 [00:01<00:01,  2.44s/it]
# mysql-5.7.20         | 79.2 MB   | :  33% 0.3302835930284445/1 [00:01<00:02,  3.32s/it]
#
#
#
# libllvm14-14.0.6     | 33.4 MB   | :  75% 0.7490261779314344/1 [00:01<00:00,  1.55s/it]
# kaleido-core-0.2.1   | 59.2 MB   | :  45% 0.44983499658276566/1 [00:01<00:01,  2.11s/it]
#
#
# qt-main-5.15.2       | 53.7 MB   | :  46% 0.4551328615245724/1 [00:01<00:01,  2.49s/it]
#
# mysql-5.7.20         | 79.2 MB   | :  37% 0.37070636113043326/1 [00:01<00:01,  3.08s/it]
#
#
#
# libllvm14-14.0.6     | 33.4 MB   | :  82% 0.820696600210052/1 [00:01<00:00,  1.52s/it]
#
# qt-webengine-5.15.9  | 53.8 MB   | :  66% 0.6581035242964469/1 [00:01<00:00,  2.20s/it]
#
#
# qt-main-5.15.2       | 53.7 MB   | :  50% 0.5008499819720182/1 [00:01<00:01,  2.45s/it]
# mysql-5.7.20         | 79.2 MB   | :  41% 0.40856573418205194/1 [00:01<00:01,  3.05s/it]
#
#
#
# libllvm14-14.0.6     | 33.4 MB   | :  89% 0.8942407590188295/1 [00:01<00:00,  1.51s/it]
#
# qt-webengine-5.15.9  | 53.8 MB   | :  71% 0.7092635155845098/1 [00:01<00:00,  2.18s/it]
#
#
# qt-main-5.15.2       | 53.7 MB   | :  55% 0.5512261720192038/1 [00:01<00:01,  2.41s/it]
# mysql-5.7.20         | 79.2 MB   | :  45% 0.4497772392226161/1 [00:01<00:01,  2.86s/it]
#
# qt-webengine-5.15.9  | 53.8 MB   | :  77% 0.765655778708852/1 [00:01<00:00,  2.06s/it]
#
#
#
# libllvm14-14.0.6     | 33.4 MB   | :  97% 0.9705955226228469/1 [00:01<00:00,  1.47s/it]
#
#
# qt-main-5.15.2       | 53.7 MB   | :  61% 0.6080085827660314/1 [00:01<00:00,  2.20s/it]
# mysql-5.7.20         | 79.2 MB   | :  49% 0.48625632263172786/1 [00:01<00:01,  2.91s/it]
#
# qt-webengine-5.15.9  | 53.8 MB   | :  82% 0.8208853147584655/1 [00:01<00:00,  1.99s/it]
#
#
# qt-main-5.15.2       | 53.7 MB   | :  67% 0.6677029120126964/1 [00:01<00:00,  2.03s/it]
# mysql-5.7.20         | 79.2 MB   | :  53% 0.5345664601194705/1 [00:01<00:01,  2.70s/it]
#
#
# qt-main-5.15.2       | 53.7 MB   | :  74% 0.7396272989586781/1 [00:01<00:00,  1.80s/it]
#
# qt-webengine-5.15.9  | 53.8 MB   | :  89% 0.8918116663169166/1 [00:01<00:00,  1.83s/it]
# mysql-5.7.20         | 79.2 MB   | :  59% 0.5903695985236793/1 [00:01<00:01,  2.48s/it]
#
#
# qt-main-5.15.2       | 53.7 MB   | :  81% 0.808057383704855/1 [00:01<00:00,  1.69s/it]
#
# qt-webengine-5.15.9  | 53.8 MB   | :  98% 0.9769814245407942/1 [00:01<00:00,  1.62s/it]
# mysql-5.7.20         | 79.2 MB   | :  64% 0.6390741044807097/1 [00:02<00:00,  2.35s/it]
#
#
# qt-main-5.15.2       | 53.7 MB   | :  88% 0.8767786603010157/1 [00:02<00:00,  1.66s/it]
# mysql-5.7.20         | 79.2 MB   | :  69% 0.6865955050298769/1 [00:02<00:00,  2.35s/it]
#
#
# qt-main-5.15.2       | 53.7 MB   | :  95% 0.9466647042971112/1 [00:02<00:00,  1.75s/it]
# mysql-5.7.20         | 79.2 MB   | :  73% 0.7295816681822357/1 [00:02<00:00,  2.82s/it]
# mysql-5.7.20         | 79.2 MB   | :  96% 0.9628506177659072/1 [00:02<00:00,  2.38s/it]
#
#
#
#
# python-3.12.2        | 30.8 MB   | :   0% 0.0005070463002532972/1 [00:03<1:47:20, 6443.95s/it]
#
#
#
#
# python-3.12.2        | 30.8 MB   | :  10% 0.09988812114989956/1 [00:03<00:21, 23.94s/it]
#
#
#
#
# python-3.12.2        | 30.8 MB   | :  21% 0.21143830720562495/1 [00:03<00:07,  9.81s/it]
#
#
#
#
# python-3.12.2        | 30.8 MB   | :  29% 0.2905375300451393/1 [00:03<00:04,  6.60s/it]
#
#
#
#
# python-3.12.2        | 30.8 MB   | :  39% 0.39296088269630536/1 [00:03<00:02,  4.30s/it]
#
#
#
#
# python-3.12.2        | 30.8 MB   | :  48% 0.4806798926401258/1 [00:03<00:01,  3.27s/it]
#
#
#
#
#
# scipy-1.12.0         | 23.3 MB   | :   0% 0.0006691887316034876/1 [00:03<1:36:07, 5771.00s/it]
#
#
#
#
# python-3.12.2        | 30.8 MB   | :  56% 0.5648495784821731/1 [00:03<00:01,  2.65s/it]
#
#
#
#
#
# scipy-1.12.0         | 23.3 MB   | :  10% 0.10238587593533359/1 [00:03<00:24, 27.47s/it]
#
#
#
#
# python-3.12.2        | 30.8 MB   | :  64% 0.6449628939221941/1 [00:04<00:00,  2.29s/it]
#
#
#
#
#
# scipy-1.12.0         | 23.3 MB   | :  19% 0.19138797723859743/1 [00:04<00:10, 12.98s/it]
#
#
#
#
# python-3.12.2        | 30.8 MB   | :  72% 0.721526885260442/1 [00:04<00:00,  2.02s/it]
#
#
#
#
#
# scipy-1.12.0         | 23.3 MB   | :  27% 0.26566792644658455/1 [00:04<00:06,  8.35s/it]
#
#
#
#
# python-3.12.2        | 30.8 MB   | :  80% 0.8006261080999564/1 [00:04<00:00,  1.82s/it]
#
#
#
#
#
# scipy-1.12.0         | 23.3 MB   | :  36% 0.35667759394465887/1 [00:04<00:03,  5.38s/it]
#
#
#
#
# python-3.12.2        | 30.8 MB   | :  88% 0.8847957939420037/1 [00:04<00:00,  1.72s/it]
#
#
#
#
#
# scipy-1.12.0         | 23.3 MB   | :  44% 0.44434131778471575/1 [00:04<00:02,  3.86s/it]
#
#
#
#
# python-3.12.2        | 30.8 MB   | :  96% 0.9573034148782251/1 [00:04<00:00,  1.64s/it]
#
#
#
#
#
# scipy-1.12.0         | 23.3 MB   | :  56% 0.561449345815326/1 [00:04<00:01,  2.70s/it]
#
#
#
#
#
#
# mathjax-2.7.7        | 21.2 MB   | :   0% 0.0007353142806569484/1 [00:04<1:43:36, 6220.83s/it]
#
#
#
#
#
# scipy-1.12.0         | 23.3 MB   | :  67% 0.6691887316034876/1 [00:04<00:00,  2.09s/it]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | :   0% 0.0008009386782302188/1 [00:04<1:36:40, 5805.64s/it]
#
#
#
#
#
#
# mathjax-2.7.7        | 21.2 MB   | :  16% 0.16323977030584255/1 [00:04<00:17, 20.32s/it]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | :   4% 0.04004693391151094/1 [00:04<01:21, 84.50s/it]
#
#
#
#
#
# scipy-1.12.0         | 23.3 MB   | :  76% 0.7615367765647688/1 [00:04<00:00,  2.02s/it]
#
#
#
#
#
#
#
#
# pandas-2.2.1         | 15.4 MB   | :   0% 0.0010174177522631242/1 [00:04<1:21:17, 4882.06s/it]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | :   6% 0.061672278223726854/1 [00:04<00:49, 52.28s/it]
#
#
#
#
#
#
#
#
# pandas-2.2.1         | 15.4 MB   | :  14% 0.13531656105099552/1 [00:05<00:22, 26.54s/it]
#
#
#
#
#
#
#
#
#
# arrow-cpp-14.0.2     | 11.7 MB   | :   0% 0.001340927777322181/1 [00:05<1:03:05, 3790.48s/it]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | :   8% 0.07769105178833123/1 [00:05<00:36, 39.18s/it]
#
#
#
#
#
#
#
#
#
# arrow-cpp-14.0.2     | 11.7 MB   | :   3% 0.02547762776912144/1 [00:05<02:22, 146.09s/it]
#
#
#
#
#
#
#
#
#
# arrow-cpp-14.0.2     | 11.7 MB   | :   4% 0.04156876109698761/1 [00:05<01:16, 79.46s/it]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | :   9% 0.09130700931824495/1 [00:05<00:28, 31.47s/it]
#
#
#
#
#
#
#
#
#
# arrow-cpp-14.0.2     | 11.7 MB   | :   6% 0.059000822202175965/1 [00:05<00:45, 48.44s/it]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | :  10% 0.10332108949169823/1 [00:05<00:23, 26.27s/it]
#
#
#
#
#
#
#
#
#
# arrow-cpp-14.0.2     | 11.7 MB   | :   8% 0.07509195553004214/1 [00:05<00:30, 33.36s/it]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | :  11% 0.1145342309869213/1 [00:05<00:19, 22.32s/it]
#
#
#
#
#
#
#
#
#
# arrow-cpp-14.0.2     | 11.7 MB   | :   9% 0.09118308885790831/1 [00:05<00:22, 24.34s/it]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | :  12% 0.12494643380391414/1 [00:05<00:17, 19.46s/it]
#
#
#
#
#
#
#
#
# pandas-2.2.1         | 15.4 MB   | :  21% 0.20958805696620358/1 [00:05<00:14, 18.67s/it]
#
#
#
#
#
#
#
#
#
# arrow-cpp-14.0.2     | 11.7 MB   | :  11% 0.10727422218577448/1 [00:05<00:16, 18.55s/it]
#
#
#
#
#
#
# mathjax-2.7.7        | 21.2 MB   | :  25% 0.25000685542336243/1 [00:05<00:12, 16.79s/it]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | :  14% 0.13535863662090697/1 [00:05<00:14, 17.11s/it]
#
#
#
#
#
#
#
#
#
# arrow-cpp-14.0.2     | 11.7 MB   | :  12% 0.12336535551364065/1 [00:05<00:12, 14.72s/it]
#
#
#
#
#
# scipy-1.12.0         | 23.3 MB   | :  84% 0.8418394243571873/1 [00:05<00:00,  5.13s/it]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | :  15% 0.14577083943789984/1 [00:05<00:13, 15.28s/it]
#
#
#
#
#
#
#
#
#
# arrow-cpp-14.0.2     | 11.7 MB   | :  14% 0.140797416618829/1 [00:05<00:10, 11.89s/it]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | :  16% 0.15618304225489268/1 [00:06<00:11, 14.04s/it]
#
#
#
#
#
#
#
#
#
# arrow-cpp-14.0.2     | 11.7 MB   | :  16% 0.15688854994669518/1 [00:06<00:08, 10.24s/it]
#
#
#
#
#
#
#
#
# pandas-2.2.1         | 15.4 MB   | :  26% 0.25537185581804417/1 [00:06<00:11, 15.80s/it]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | :  17% 0.1657943063936553/1 [00:06<00:10, 13.11s/it]
#
#
#
#
#
#
#
#
#
# arrow-cpp-14.0.2     | 11.7 MB   | :  17% 0.17297968327456134/1 [00:06<00:07,  9.07s/it]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | :  18% 0.17540557053241793/1 [00:06<00:10, 12.56s/it]
#
#
#
#
#
#
#
#
#
# arrow-cpp-14.0.2     | 11.7 MB   | :  19% 0.18907081660242753/1 [00:06<00:06,  8.34s/it]
#
#
#
#
#
#
# mathjax-2.7.7        | 21.2 MB   | :  30% 0.30147885506934885/1 [00:06<00:10, 15.40s/it]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | :  19% 0.18501683467118055/1 [00:06<00:09, 12.23s/it]
#
#
#
#
#
#
#
#
#
# arrow-cpp-14.0.2     | 11.7 MB   | :  21% 0.20516194993029369/1 [00:06<00:06,  7.71s/it]
#
#
#
#
#
#
#
#
# pandas-2.2.1         | 15.4 MB   | :  29% 0.28792922389046416/1 [00:06<00:10, 14.24s/it]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | :  19% 0.19462809880994317/1 [00:06<00:09, 11.82s/it]
#
#
#
#
#
#
#
#
#
# arrow-cpp-14.0.2     | 11.7 MB   | :  22% 0.22125308325815987/1 [00:06<00:05,  7.32s/it]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | :  20% 0.20423936294870582/1 [00:06<00:09, 11.53s/it]
#
#
#
#
#
#
#
#
#
# arrow-cpp-14.0.2     | 11.7 MB   | :  24% 0.23734421658602603/1 [00:06<00:05,  7.02s/it]
#
#
#
#
#
#
#
#
# pandas-2.2.1         | 15.4 MB   | :  31% 0.31336466769704224/1 [00:06<00:08, 13.09s/it]
#
#
#
#
#
# scipy-1.12.0         | 23.3 MB   | :  90% 0.9000588440066908/1 [00:06<00:00,  6.83s/it]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | :  21% 0.21385062708746844/1 [00:06<00:08, 11.26s/it]
#
#
#
#
#
#
#
#
#
# arrow-cpp-14.0.2     | 11.7 MB   | :  25% 0.25477627769121436/1 [00:06<00:05,  6.78s/it]
#
#
#
#
#
#
#
#
# pandas-2.2.1         | 15.4 MB   | :  33% 0.33473044049456785/1 [00:06<00:07, 11.66s/it]
#
#
#
#
#
#
# mathjax-2.7.7        | 21.2 MB   | :  34% 0.3360386262602254/1 [00:06<00:09, 14.53s/it]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | :  26% 0.2595041317465909/1 [00:06<00:03,  5.22s/it]
#
#
#
#
#
# scipy-1.12.0         | 23.3 MB   | :  94% 0.942886922829314/1 [00:06<00:00,  6.19s/it]
#
#
#
#
#
#
#
#
#
# arrow-cpp-14.0.2     | 11.7 MB   | :  36% 0.3607095720996667/1 [00:06<00:01,  2.50s/it]
#
#
#
#
#
#
#
#
# pandas-2.2.1         | 15.4 MB   | :  47% 0.46597733053651086/1 [00:06<00:02,  4.83s/it]
#
#
#
#
#
#
# mathjax-2.7.7        | 21.2 MB   | :  41% 0.41104068288723417/1 [00:06<00:05,  9.43s/it]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | :  37% 0.3676308533076704/1 [00:06<00:01,  2.29s/it]
#
#
#
#
#
#
#
#
#
# arrow-cpp-14.0.2     | 11.7 MB   | :  54% 0.5417348220381611/1 [00:06<00:00,  1.25s/it]
#
#
#
#
#
#
#
#
# pandas-2.2.1         | 15.4 MB   | :  63% 0.6338512596599264/1 [00:06<00:00,  2.57s/it]
#
#
#
#
#
#
# mathjax-2.7.7        | 21.2 MB   | :  55% 0.5536916533346822/1 [00:06<00:02,  4.95s/it]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | :  48% 0.47896132958167087/1 [00:06<00:00,  1.60s/it]
#
#
#
#
#
#
#
#
#
# arrow-cpp-14.0.2     | 11.7 MB   | :  77% 0.7670106886282875/1 [00:06<00:00,  1.21it/s]
#
#
#
#
#
#
#
#
# pandas-2.2.1         | 15.4 MB   | :  84% 0.8403870633693405/1 [00:07<00:00,  1.56s/it]
#
#
#
#
#
#
# mathjax-2.7.7        | 21.2 MB   | :  67% 0.6735478810817647/1 [00:07<00:01,  3.39s/it]
#
#
#
#
#
#
#
#
#
# arrow-cpp-14.0.2     | 11.7 MB   | :  96% 0.9587633607853594/1 [00:07<00:00,  1.42it/s]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | :  68% 0.6832006925303766/1 [00:07<00:00,  1.01it/s]
#
#
#
#
#
#
# mathjax-2.7.7        | 21.2 MB   | :  84% 0.8419348513522059/1 [00:07<00:00,  2.18s/it]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | :  80% 0.8033414942649095/1 [00:07<00:00,  1.07it/s]
#
#
#
#
#
#
# mathjax-2.7.7        | 21.2 MB   | :  99% 0.9926742788868803/1 [00:07<00:00,  1.64s/it]
#
#
#
#
#
#
#
#
#
#
# libclang13-14.0.6    | 9.8 MB    | :   0% 0.0016025206836573897/1 [00:07<1:16:36, 4603.49s/it]
#
#
#
#
#
#
#
#
#
#
# libclang13-14.0.6    | 9.8 MB    | :  38% 0.3846049640777735/1 [00:07<00:08, 13.74s/it]
#
#
#
#
#
#
#
#
#
#
#
# numpy-base-1.26.4    | 7.7 MB    | :   0% 0.0020306342695560406/1 [00:07<1:01:32, 3700.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 7.6 MB    | :   0% 0.002050079549442966/1 [00:07<1:01:26, 3693.63s/it]
#
#
#
#
#
#
#
#
#
#
# libclang13-14.0.6    | 9.8 MB    | :  63% 0.6313931493610115/1 [00:07<00:02,  7.36s/it]
#
#
#
#
#
#
#
#
#
#
#
# numpy-base-1.26.4    | 7.7 MB    | :  34% 0.33505465447674665/1 [00:07<00:10, 16.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 7.6 MB    | :  38% 0.3751645575480628/1 [00:07<00:09, 14.42s/it]
#
#
#
#
#
#
#
#
#
#
# libclang13-14.0.6    | 9.8 MB    | :  85% 0.8509384830220739/1 [00:07<00:00,  4.78s/it]
#
#
#
#
#
#
#
#
#
#
#
# numpy-base-1.26.4    | 7.7 MB    | :  74% 0.7391508741183987/1 [00:07<00:01,  6.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 7.6 MB    | :  63% 0.6293744216789906/1 [00:07<00:02,  7.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 7.6 MB    | :  99% 0.9922385019303956/1 [00:07<00:00,  3.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyterlab-4.2.0     | 7.6 MB    | :   0% 0.00205255410441918/1 [00:07<1:04:08, 3856.41s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# babel-2.14.0         | 7.3 MB    | :   0% 0.0021530273662078254/1 [00:07<1:01:13, 3681.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyterlab-4.2.0     | 7.6 MB    | :  40% 0.40435315857057846/1 [00:08<00:08, 13.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# babel-2.14.0         | 7.3 MB    | :  39% 0.39185098064982427/1 [00:08<00:08, 14.44s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openblas-0.3.27      | 5.5 MB    | :   0% 0.0028590374480857153/1 [00:08<46:41, 2809.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyterlab-4.2.0     | 7.6 MB    | :  79% 0.7902333302013843/1 [00:08<00:01,  6.06s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# babel-2.14.0         | 7.3 MB    | :  85% 0.8482927822858832/1 [00:08<00:00,  5.55s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openblas-0.3.27      | 5.5 MB    | :  58% 0.5775255645133145/1 [00:08<00:04,  9.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.27   | 5.3 MB    | :   0% 0.0029263690607916376/1 [00:08<46:15, 2783.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# plotly-5.22.0        | 5.1 MB    | :   0% 0.0030781225781906824/1 [00:08<44:04, 2652.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openblas-0.3.27      | 5.5 MB    | :  95% 0.9520594702125432/1 [00:08<00:00,  5.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.27   | 5.3 MB    | :  56% 0.5618628596719945/1 [00:08<00:04, 10.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# plotly-5.22.0        | 5.1 MB    | :  60% 0.5971557801689924/1 [00:08<00:03,  9.76s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# libllvm14-14.0.6     | 33.4 MB   | : 100% 1.0/1 [00:09<00:00,  1.47s/it]
#
# qt-webengine-5.15.9  | 53.8 MB   | : 100% 1.0/1 [00:11<00:00,  1.62s/it]
#
#
# qt-main-5.15.2       | 53.7 MB   | : 100% 1.0/1 [00:20<00:00,  1.75s/it]
#
#
#
#
# python-3.12.2        | 30.8 MB   | : 100% 1.0/1 [00:22<00:00,  1.64s/it]
# kaleido-core-0.2.1   | 59.2 MB   | : 100% 1.0/1 [00:39<00:00,  2.00s/it]
#
#
#
#
#
#
#
#
#
# arrow-cpp-14.0.2     | 11.7 MB   | : 100% 1.0/1 [00:40<00:00,  1.42it/s]
#
#
#
#
#
# scipy-1.12.0         | 23.3 MB   | : 100% 1.0/1 [00:42<00:00, 171.04s/it]
#
#
#
#
#
# scipy-1.12.0         | 23.3 MB   | : 100% 1.0/1 [00:42<00:00, 171.04s/it]
#
#
#
#
#
#
#
#
# pandas-2.2.1         | 15.4 MB   | : 100% 1.0/1 [00:46<00:00, 87.42s/it]
#
#
#
#
#
#
#
#
# mysql-5.7.20         | 79.2 MB   | : 100% 1.0/1 [00:57<00:00,  2.38s/it]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | : 100% 1.0/1 [01:12<00:00, 144.24s/it]
#
#
#
#
#
#
#
# libboost-1.82.0      | 19.5 MB   | : 100% 1.0/1 [01:12<00:00, 144.24s/it]
#
#
#
#
#
#
#
#
#
#
# libclang13-14.0.6    | 9.8 MB    | : 100% 1.0/1 [01:13<00:00,  4.78s/it]
#
#
#
#
#
#
#
#
#
#
#
# numpy-base-1.26.4    | 7.7 MB    | : 100% 1.0/1 [01:14<00:00,  6.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 7.6 MB    | : 100% 1.0/1 [01:15<00:00,  3.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# babel-2.14.0         | 7.3 MB    | : 100% 1.0/1 [01:16<00:00,  5.55s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyterlab-4.2.0     | 7.6 MB    | : 100% 1.0/1 [01:17<00:00,  6.06s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openblas-0.3.27      | 5.5 MB    | : 100% 1.0/1 [01:17<00:00,  5.28s/it]
#
#
#
#
#
#
# mathjax-2.7.7        | 21.2 MB   | : 100% 1.0/1 [01:22<00:00,  1.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.27   | 5.3 MB    | : 100% 1.0/1 [01:23<00:00, 94.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.27   | 5.3 MB    | : 100% 1.0/1 [01:23<00:00, 94.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# plotly-5.22.0        | 5.1 MB    | : 100% 1.0/1 [01:27<00:00, 101.63s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# plotly-5.22.0        | 5.1 MB    | : 100% 1.0/1 [01:27<00:00, 101.63s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %%
#!conda install matplotlib --yes

# %%
#!conda install scipy --yes

# %%
#!conda install xlrd --yes

# %%
#!conda install openpyxl --yes

# %% [markdown]
# # Notes of BPL_YEAST_AIR_Fedbatch

# %% [markdown]
# Now specific installation and the run simulations. Start with connecting to Github. Then upload the two files:
#
# * FMU - BPL_YEAST_AIR_Fedbatch_linux_jm_cs.fmu
# * Setup-file - BPL_YEAST_AIR_Fedbatch_fmpy_explore

# %%
# %%bash
# git clone https://github.com/janpeter19/BPL_YEAST_AIR_Fedbatch
# Out:
# Cloning into 'BPL_YEAST_AIR_Fedbatch'...

# %%
# %cd BPL_YEAST_AIR_Fedbatch
# Out:
# /content/BPL_YEAST_AIR_Fedbatch

# %% [markdown]
# # BPL_YEAST_AIR_Fedbatch - demo
#
# Author: Jan Peter Axelsson
#
# This notebook demonstrate yeast fedbatch cultivation. We look at impact of changes in the glucose feeding. We also take a look at tuning of the DO-control system. Both liquid- and gasphase are included in the model. The culture growth and metabolism are formulated in relation to to the respiratory capacity [1] and the model is exapanded to describe also the gas phase as well as the culture heat production [2]. The model was derived mainly from continuous culture data but proved to capture dynamic aspects well of ethanol production and consumption [3].
#
# Interaction with the compiled model as FMU is mainly through the simplified commands: par(), init(), newplot(), simu() etc. The last simulation is always available in the workspace and called 'sim_res'. The command describe() brings mainly up description infomration from the actual Modelica code from the FMU but is complemented with information given in the dedicated Python setup-file.
#
# The idea is to demonstrate how simulations and varyiing conditions can provide some process insight that can support the experimetnal work. I hope that at the end of this session you are ready to formulate your own questions you want to address with simulations - and you can just go on in this notebook! Just press the field "+Code" in the upper left part of notebook interface and you get a new "cell" where you write your own code. You can copy and paste from cells above using ctrol-c and ctrl-p as usual and edit the cell. When your are ready to execute the cell just press the "play button" to the left in the cell or press shift-enter as in "ordinary" Jupyter notebooks.
#
# After a session you may want to save your own notebook. That you can do on your Google Drive account and I refer to Colab instructions for how to do this. It is easy.
#
# Enjoy!

# %%
run -i BPL_YEAST_AIR_Fedbatch_DOcontrol_fmpy_explore.py
# Out:
# Linux - run FMU pre-comiled OpenModelica 1.21.0
#
# Model for bioreactor has been setup. Key commands:
#  - par()       - change of parameters and initial values
#  - init()      - change initial values only
#  - simu()      - simulate and plot
#  - newplot()   - make a new plot
#  - show()      - show plot from previous simulation
#  - disp()      - display parameters and initial values from the last simulation
#  - describe()  - describe culture, broth, parameters, variables with values/units
#
# Note that both disp() and describe() takes values from the last simulation
# and the command process_diagram() brings up the main configuration
#
# Brief information about a command by help(), eg help(simu)
# Key system information is listed with the command system_info()

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [36/2.54, 30/2.54]

# %% [markdown]
# ## About the process model
#
# We can get information about the process, liquid- and gas-phase by the command describe(). This command can also be used to bring up information about a specific variable or parameter. However, you should use describe() after a simulation to get the valued used during the simulation.

# %%
describe('culture'); print(); #describe('liquidphase'); print(); describe('gasphase')                                     # Pump schedule parameter
# Out:
# Saccharomyces cerevisae - default parameters for strain H1022

# %%
process_diagram()

# %% [markdown]
# The model of the process has parameters both for culture, gas_liquid_transfer, as well as feeding procedure. The paramters that are available for changes you find by the command disp() and you get a long list and you change by them by command par(). The model has even more parameters in the background but not made available for interaction.

# %% [markdown]
# ## First simulations - adjusting start of substrate feeding

# %%
# Culture parameters and others at default values
par(qO2lim=0.0069)

# Process initial conditions
init(V_start=4.5, VG_start=4.5*30, VX_start=4.5*2, VE_start=4.5*0)

# Feed profile
par(t_startExp=9, F_startExp=0.044, mu_feed=0.20, F_max=0.18)

# DO-control parameters
par(K=10, Ti=0.5)

# Simulate and plot
newplot(title='Yeast fedbatch cultivation', plotType='Overview')
simu(20)

# %% [markdown]
# Now we can get value of broth volume as well as the headspace and values are the last ones in the simulation

# %%
describe('bioreactor.V')
# Out:
# Reactor broth volume : 5.892 [ L ]

# %%
describe('bioreactor.V_gasphase')
# Out:
# Volume of the gas phase : 2.108 [ L ]

# %%
# Take a look at the parameters available to adjust the dosage scheme
disp('dosage', decimals=4)
# Out:
# F_start : 0.0
# mu_feed : 0.2
# t_startExp : 9
# F_startExp : 0.044
# F_max : 0.18

# %%
# Let us start the feeding just after the batch phase has ended and keep other parameters the same
par(t_startExp=8.1)

# Simulate and plot
newplot(title='Yeast fedbatch cultivation', plotType='Overview')
simu(20)

# %% [markdown]
# The increase of DO to about 50 % at end of batch phase should be possible to detect easily. This simulation is more realistic and we use these settings from now on.

# %% [markdown]
# ## DO-control  - tuning of PI-regulator parameters
#
# Let us focus on the DO-control system and choose a more limited plotType. We study the impact of PI control parameters and see if we can decrease the control error without looing stability.

# %%
# Let us take a closer look at the DO-control system and try to make control error smaller by increaseing K
newplot(title='Yeast fedbatch cultivation - DO-control - increase K', plotType='Focus DO-control')
for value in [10, 20, 40]: par(K=value); simu(20)

# Reset K to the original value
par(K=10)

# %% [markdown]
# We see that by a higher control gain K the DO-control error get smaller and the stability of the control system is maintained.

# %% [markdown]
# **Exercise** I leave for you to study the impact variation of the Ti-parameter. Just make a new cell below. Then copy and paste the cell above and change parameter to Ti.

# %% [markdown]
# ## Sensitivity to changes in feed-profile
#
# Now, let us focus on investigating impact of changes in the feed-profile. The goal is to increase the produced cell mass without accumulation of by-product ethanol. Simulation can bring some insight into how behaviour of the differen variables change when by-product is formed. This insight can help to interpret experimental results.

# %%
# Let us check the sensitivity to changes in the feed profile design
newplot(title='Yeast fedbatch cultivation', plotType='Overview')
for value in [0.044, 0.038, 0.050]: par(F_startExp=value); simu(20)

# %% [markdown]
# The variation in F_start has an impact and we see that the actual growth rate during fedbatch phase do converge to the set growth rate of the feed, but i takes more than 5 hours.

# %%
# Let us investigate a feedprofile that is closer to the maximal capacity
newplot(title='Yeast fedbatch cultivation', plotType='Overview')
par(F_startExp=0.044, mu_feed=0.20); simu(20)
par(F_startExp=0.050, mu_feed=0.22); simu(20)
par(F_startExp=0.057, mu_feed=0.26); simu(20)

# %%
# And let us see what happens if the feedprofile exceed the culture capacity
newplot(title='Yeast fedbatch cultivation', plotType='Overview')
par(F_startExp=0.057, mu_feed=0.26); simu(20)
par(F_startExp=0.063, mu_feed=0.28); simu(20)
par(F_startExp=0.044, mu_feed=0.20)

# %% [markdown]
# Note that with the feedprofile that exceed culture respiratory capacity, ethanol is accumulated during time 8-12.5 hours. When the feedprofile then is constant from time 12.5 hours and on, then the accumulated ethanol is consumed over about an hour. This leads to a higher oxygen demand and heat production during this time. The specific cell growth rate is also slightly higher during this period.

# %% [markdown]
# **Exercise** You can investiate the impact of changing the maximal feedrate F_max. Make sure that the DO level do not get too low.

# %% [markdown]
# ## Make your own diagrams
#
# There are a couple of pre-defined plotType for the application that you make by the command newplot(). The command result in a list "diagrams" that desccrige the commands that make the plot when you call simu() or you just want to look at the last simulation again with a changed plotType using show().
#
# You can also in Jupyter notebook directly define the list "diagrams" and then that will be used for subsequent calls of simu() or show(). When you have made a diagram that you want to reuse many times you can bring it into the python-setup file and edit the newplot() commmand and add a new plotType.
#
# Below a few simple examples that show how to do a diagram directly i the notebook

# %%
# First decrease the diagram size
plt.rcParams['figure.figsize'] = [24/2.54, 20/2.54]

# %%
# Improvise and make your own diagram - cell concentration in a logaritmic plot
plt.figure()
ax1 = plt.subplot(1,1,1)
ax1.set_ylabel('X [g/L]')
ax1.set_xlabel('Time [h]')
ax1.grid()

setLines()
diagrams.clear()
diagrams.append("ax1.semilogy(sim_res['time'], sim_res['bioreactor.c[1]'], color='b', linestyle=linetype)")
show()

# %%
# - study the variation of Kla together with DO and N during cultivation
plt.figure()
ax1 = plt.subplot(3,1,1); ax2 = plt.subplot(3,1,2); ax3 = plt.subplot(3,1,3)
ax1.set_ylabel('DO [%]'); ax1.grid()
ax2.set_ylabel('Kla [1/h]'); ax2.grid()
ax3.set_ylabel('N [rpm]'); ax3.grid()
ax3.set_xlabel('Time [h]')

setLines()
diagrams.clear()
diagrams.append("ax1.plot(sim_res['time'], sim_res['DOsensor.out'], color='b', linestyle=linetype)")
diagrams.append("ax2.plot(sim_res['time'], sim_res['bioreactor.gas_liquid_transfer.Kla_O2'], color='b', linestyle=linetype)")
diagrams.append("ax3.plot(sim_res['time'], sim_res['bioreactor.N'], color='c', linestyle=linetype)")
show()

# %% [markdown]
# The relation is Kla = alpha_O2*N and we see the value of the parameter should be around 1.0, and we check below

# %%
disp('bioreactor.gas_liquid_transfer.alpha_O2')
# Out:
# alpha_O2 : 1.0

# %%
# - study the relation qO2 vs qG(G)
plt.figure()
ax1 = plt.subplot(1,1,1)
ax1.set_ylabel('qO2 []')
ax1.set_xlabel('qG []')
ax1.grid()

setLines()
diagrams.clear()
diagrams.append("ax1.plot(sim_res['bioreactor.culture.qGm'], sim_res['bioreactor.culture.qO2'], 'b*')")
par(F_start=0.057, mu_feed=0.26)
simu(20)

# %% [markdown]
# During the cultivation we have a number of data points for qG and qO2 at the same time, during different conditions. What we see in the diagram is that qO2 increase with qG until qG reach a level of just above 0.0025 and then qO2 saturats for highter qG. This what expect to see.
#
# We also see that for lower qG we have also qO2 values at saturation level. This points correspond to a situation where ethanol is consumed with the remaining respiratory capacity. Glucose is consumed by priority.

# %% [markdown]
# ## Summary
# * We have first seen an overview diagram of a typical yeast fedbatch cultivation where the feed started about an hour after the batch phase was finished. A new simulation was made where the feed started directly after detection of lack of substrate.
# * We also took a look at the DO-control system and saw that we could decrease the control error by increasing the PI-controller gain. Stability of the control system remained.
# * Then we tested variations in the feed dosage scheme and investigated the possibilities to increae the production.
# * We also saw what happens if the feed dosage exceed the culture respiratory capacity and what to look for during the experimental work.
# * Finally we saw some examples of how to improvise new diagrams.

# %% [markdown]
# ## References
#
# [1] Sonnleitner, B and O. Käppeli "Growth of *Sacharomyces cerevisiae* is controlled by its limited respiratory capacity: formulationa and verification of a hypothesis", Biotech. Bioeng., 1986.
#
# [2] von Stockar, U., Gustafsson, L., Larsson, C., Marison, I., Tissot, P. and Gnaiger E. "Thermodynamic considerations in constructing energy balances for cellular growth", Biochimica et Biophysics Acta, vol 1183, p 221-240, 1993.
#
# [3] Axelsson, J. P. "Experimental techniques and data analysis to dtermine baker's yeast ethanol dynamics", Anal. Chim. Acta, vol 213, p 151-163, 1988.

# %% [markdown]
# ## Appendix

# %%
# List of components in the process setup and also a couple of other things like liquidphase and gasphase etc
describe('parts')
# Out:
# ['airFlow_setpoint', 'airtube', 'atmosphere', 'bioreactor', 'bioreactor.culture', 'bioreactor.gas_liquid_transfer', 'compressor', 'DO_setpoint', 'dosagescheme', 'DOsensor', 'feedtank', 'N_high', 'N_low', 'PIreg', 'pump']

# %%
describe('MSL')
# Out:
# MSL: 3.2.3 - used components: RealInput, RealOutput, LimPID-components

# %%
system_info()
# Out:
# System information
#  -OS: Linux
#  -Python: 3.10.12
#  -Scipy: not installed in the notebook
#  -FMPy: 0.3.20
#  -FMU by: OpenModelica Compiler OpenModelica 1.21.0
#  -FMI: 2.0
#  -Type: ME
#  -Name: BPL_YEAST_AIR.Fedbatch_DOcontrol
#  -Generated: 2024-05-08T14:29:23Z
#  -MSL: 3.2.3
#  -Description: Bioprocess Library version 2.2.0
#  -Interaction: FMU-explore for FMPy version 1.0.0
